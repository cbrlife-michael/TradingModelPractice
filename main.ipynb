# %%
import pandas as pd

ft_basic = pd.read_pickle("./data/ft_basic.pkl")
ft_basic
# Out:
#         id        code code_adj asset_en asset_cn  contract_yr_mth exchange  \
# 0        3  AL9505.SHF   AL9505       AL       沪铝             9505      SHF
# 1        4  AL9506.SHF   AL9506       AL       沪铝             9506      SHF
# 2        5  AL9507.SHF   AL9507       AL       沪铝             9507      SHF
# 3        6  AL9508.SHF   AL9508       AL       沪铝             9508      SHF
# 4        7  CU9505.SHF   CU9505       CU       沪铜             9505      SHF
# ...    ...         ...      ...      ...      ...              ...      ...
# 6369  7259  SC2201.INE   SC2201       SC       原油             2201      INE
# 6370  7260  EB2112.DCE   EB2112       EB      苯乙烯             2112      DCE
# 6371  7261  EG2112.DCE   EG2112       EG      乙二醇             2112      DCE
# 6372  7262  JD2112.DCE   JD2112       JD       鸡蛋             2112      DCE
# 6373  7263  PG2112.DCE   PG2112       PG      LPG             2112      DCE
#
# ...

# %%
hermes_daily_main = pd.read_pickle("./data/hermes_daily_main.pkl")
hermes_daily_main
# Out:
#          bar_date ticker_symbol exchange_cd sec_short_name contract_object  \
# 0      2000-07-17         m0105        XDCE        连豆粕0105               M
# 1      2000-07-18         m0105        XDCE        连豆粕0105               M
# 2      2000-07-19         m0105        XDCE        连豆粕0105               M
# 3      2000-07-20         m0105        XDCE        连豆粕0105               M
# 4      2000-07-21         m0105        XDCE        连豆粕0105               M
# ...           ...           ...         ...            ...             ...
# 153688 2022-01-25         PK204        XZCE         郑花生204              PK
# 153689 2022-01-26         PK204        XZCE         郑花生204              PK
# 153690 2022-01-27         PK204        XZCE         郑花生204              PK
# 153691 2022-01-28         PK204        XZCE         郑花生204              PK
# 153692 2022-02-07         PK204        XZCE         郑花生204              PK
#
# ...

# %%
min_main_from_mat = pd.read_pickle("./data/min_main_from_mat.pkl")
min_main_from_mat
# Out:
#          asset_en      datetime  bar_date     open     high      low    close  \
# 0              AL  201510080900  20151008  11680.0  11690.0  11650.0  11670.0
# 1              AL  201510080901  20151008  11665.0  11675.0  11660.0  11660.0
# 2              AL  201510080902  20151008  11660.0  11665.0  11655.0  11655.0
# 3              AL  201510080903  20151008  11655.0  11660.0  11650.0  11650.0
# 4              AL  201510080904  20151008  11650.0  11650.0  11635.0  11635.0
# ...           ...           ...       ...      ...      ...      ...      ...
# 19125212       BC  202012301455  20201230  52120.0  52120.0  52100.0  52110.0
# 19125213       BC  202012301456  20201230  52110.0  52110.0  52110.0  52110.0
# 19125214       BC  202012301457  20201230  52100.0  52100.0  52080.0  52090.0
# 19125215       BC  202012301458  20201230  52090.0  52100.0  52080.0  52100.0
# 19125216       BC  202012301459  20201230  52100.0  52110.0  52070.0  52110.0
#
# ...
